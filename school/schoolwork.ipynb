# %%
import pandas as pd
video_game_reviews = pd.read_csv("ign.csv")
video_game_reviews
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# 5               5         Good
# 6               6        Awful
# 7               7      Amazing
# 8               8        Awful
# 9               9         Good
# 10             10         Good
# 11             11         Good
# 12             12         Good
# 13             13      Amazing
# 14             14      Amazing
# 15             15         Okay
# 16             16         Okay
# 17             17        Great
# 18             18     Mediocre
# 19             19         Good
# 20             20         Good
# 21             21         Good
# 22             22         Good
# 23             23         Good
# 24             24      Amazing
# 25             25         Good
# 26             26      Amazing
# 27             27         Good
# 28             28        Great
# ...

# %%
video_review.head(10)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
# 6           6        Awful                                Double Dragon: Neon
# 7           7      Amazing                                       Guild Wars 2
# 8           8        Awful                                Double Dragon: Neon
# 9           9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# ...

# %%
video_review.tail(10)
# Out:
#        Unnamed: 0 score_phrase  \
# 18615       18615      Amazing
# 18616       18616         Good
# 18617       18617        Great
# 18618       18618      Amazing
# 18619       18619         Good
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 18615                                  Zero Time Dilemma
# 18616  Batman: The Telltale Series -- Episode 1: Real...
# 18617                                               Abzu
# 18618                                          Starbound
# 18619                                    Human Fall Flat
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# 18623                                             Inside
# ...

# %%
video_game_reviews.iloc[0:5,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
video_review.iloc[19,:]
# Out:
# Unnamed: 0                                                    19
# score_phrase                                                Good
# title                                JoJo's Bizarre Adventure HD
# url               /games/jojos-bizarre-adventure/xbox-360-137717
# platform                                                Xbox 360
# score                                                          7
# genre                                                   Fighting
# editors_choice                                                 N
# release_year                                                2012
# release_month                                                  9
# release_day                                                    3
# Name: 19, dtype: object

# %%
video_review.loc[0:5,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# ...

# %%
video_review.loc[:10,["title", "genre"]]
# Out:
#                                                 title       genre
# 0                             LittleBigPlanet PS Vita  Platformer
# 1   LittleBigPlanet PS Vita -- Marvel Super Hero E...  Platformer
# 2                                Splice: Tree of Life      Puzzle
# 3                                              NHL 13      Sports
# 4                                              NHL 13      Sports
# 5                           Total War Battles: Shogun    Strategy
# 6                                 Double Dragon: Neon    Fighting
# 7                                        Guild Wars 2         RPG
# 8                                 Double Dragon: Neon    Fighting
# 9                           Total War Battles: Shogun    Strategy
# 10                            Tekken Tag Tournament 2    Fighting

# %%
pd.DataFrame(
    [
    [1,2],
    ["Boris Yeltsin", "Mikhail Gorbachev"]
    ]
)
# Out:
#                0                  1
# 0              1                  2
# 1  Boris Yeltsin  Mikhail Gorbachev

# %%
video_review = pd.DataFrame(
    {
    "column1": [1, "Boris Yeltsin"],
    "column2": [2, "Mikhail Gorbachev"]
    }
)
video_review
# Out:
#          column1            column2
# 0              1                  2
# 1  Boris Yeltsin  Mikhail Gorbachev

# %%
video_review.mean(axis=1)
# Out:
# 0   NaN
# 1   NaN
# dtype: float64

# %%
video_review.corr
# Out:
# <bound method DataFrame.corr of          column1            column2
# 0              1                  2
# 1  Boris Yeltsin  Mikhail Gorbachev>

# %%
import pandas as pd
video_review = pd.read_csv("ign.csv")
video_review
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# 5               5         Good
# 6               6        Awful
# 7               7      Amazing
# 8               8        Awful
# 9               9         Good
# 10             10         Good
# 11             11         Good
# 12             12         Good
# 13             13      Amazing
# 14             14      Amazing
# 15             15         Okay
# 16             16         Okay
# 17             17        Great
# 18             18     Mediocre
# 19             19         Good
# 20             20         Good
# 21             21         Good
# 22             22         Good
# 23             23         Good
# 24             24      Amazing
# 25             25         Good
# 26             26      Amazing
# 27             27         Good
# 28             28        Great
# ...

# %%
video_review.corr()
# Out:
#                Unnamed: 0     score  release_year  release_month  release_day
# Unnamed: 0       1.000000  0.035579      0.893394      -0.096676     0.010068
# score            0.035579  1.000000      0.062716       0.007632     0.020079
# release_year     0.893394  0.062716      1.000000      -0.115515     0.016867
# release_month   -0.096676  0.007632     -0.115515       1.000000    -0.067964
# release_day      0.010068  0.020079      0.016867      -0.067964     1.000000

# %%
video_review.count()
# Out:
# Unnamed: 0        18625
# score_phrase      18625
# title             18625
# url               18625
# platform          18625
# score             18625
# genre             18589
# editors_choice    18625
# release_year      18625
# release_month     18625
# release_day       18625
# dtype: int64

# %%
video_review[video_review["platform"] == "Xbox One"]["score"].plot(kind="hist")

# %%
reviews[reviews["platform"] == "Xbox One"]["score"].plot(kind="hist")

# %%
import pandas as pd
video_game_review = pd.read_csv("ign.csv")
video_game_review [video_game_review ["genre"] == "Sports"]["score"].plot(kind="hist")
